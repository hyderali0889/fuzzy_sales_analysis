# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as mp 
import seaborn as sb

# %%
customers = pd.read_csv('Data/customers.csv')
orders = pd.read_csv('Data/orders.csv')
order_items = pd.read_csv('Data/order_items.csv')
products = pd.read_csv('Data/products.csv')

# %%
print(f"The leading 10 rows are as folows: \n {customers.head(10)}  {orders.head(10)}  {order_items.head(10)}  {products.head(10)}")
# Out:
# The leading 10 rows are as folows:
#     customer_id  country signup_date
# 0            1    Spain  2023-05-15
# 1            2    Italy  2023-02-10
# 2            3    Spain  2023-10-23
# 3            4   France  2023-01-03
# 4            5    Italy  2024-02-05
# 5            6    Italy  2023-07-13
# 6            7    Spain  2024-04-07
# 7            8   France  2023-04-20
# 8            9  Morocco  2023-08-09
# 9           10    Italy  2024-01-05     order_id  customer_id  order_date     status
# 0         1          103  2024-10-31  Completed
# 1         2          271  2024-10-12  Completed
# 2         3          107  2024-05-23  Completed
# 3         4           72  2024-01-19  Completed
# 4         5          189  2024-01-18  Completed
# 5         6           21  2024-09-13  Completed
# 6         7          103  2024-03-18  Completed
# 7         8          122  2024-06-23  Cancelled
# 8         9          215  2024-07-12  Completed
# ...

# %%
# # customers.info()
# # orders.info()
# order_items.info()

# # products.info()

# %%
customers.nunique()
orders.nunique()
order_items.nunique()
products.nunique()
# Out:
# product_id      50
# product_name    50
# category         4
# dtype: int64

# %%
# # customers.duplicated().sum()

# # orders.duplicated().sum()
# # order_items.duplicated().sum()
# products.duplicated().sum()

# %%
customers["customer_id"].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: customer_id, dtype: int64

# %%
orders["customer_id"].head()
# Out:
# 0    103
# 1    271
# 2    107
# 3     72
# 4    189
# Name: customer_id, dtype: int64

# %%
customers_with_orders = customers[customers["customer_id"].isin(orders["customer_id"])]
customers_without_orders = customers[~customers["customer_id"].isin(orders["customer_id"])]


order_items_with_orders = order_items[order_items["order_id"].isin(orders["order_id"])]
order_items_without_orders = order_items[~order_items["order_id"].isin(orders["order_id"])]

order_items_with_products = order_items[order_items["product_id"].isin(products["product_id"])]
order_items_without_products = order_items[~order_items["product_id"].isin(products["product_id"])]

# %%
len(customers_with_orders)
# Out:
# 285

# %%
len(customers_without_orders)
# Out:
# 15

# %%
len(order_items_with_orders)
# Out:
# 2000

# %%
len(order_items_without_orders)
# Out:
# 0

# %%
len(order_items_with_products)
# Out:
# 2000

# %%
len(order_items_without_products)
# Out:
# 0

# %%
orders["status"].value_counts()
# Out:
# status
# Completed    805
# Cancelled    103
# Returned      92
# Name: count, dtype: int64

# %%
order_items["order_id"].duplicated().sum()
# Out:
# np.int64(1139)

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    2000 non-null   int64
#  1   product_id  2000 non-null   int64
#  2   quantity    2000 non-null   int64
#  3   price       2000 non-null   int64
# dtypes: int64(4)
# memory usage: 62.6 KB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     1000 non-null   int64
#  1   customer_id  1000 non-null   int64
#  2   order_date   1000 non-null   object
#  3   status       1000 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 31.4+ KB

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  300 non-null    int64
#  1   country      300 non-null    object
#  2   signup_date  300 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 7.2+ KB

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    50 non-null     int64
#  1   product_name  50 non-null     object
#  2   category      50 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %%
completed_orders = orders[orders["status"] == "Completed"]

all_orders = pd.merge(completed_orders,order_items, how="inner", on="order_id" )

# %%
all_orders.head()
all_orders["status"].value_counts()
# Out:
# status
# Completed    1625
# Name: count, dtype: int64

# %%
orders_with_products=pd.merge(all_orders,products,how="inner",on="product_id")

# %%
orders_with_products.head()
# Out:
#    order_id  customer_id  order_date     status  product_id  quantity  price  \
# 0         1          103  2024-10-31  Completed          13         4     58
# 1         3          107  2024-05-23  Completed          18         1     25
# 2         3          107  2024-05-23  Completed          24         4     41
# 3         3          107  2024-05-23  Completed          42         2     66
# 4         3          107  2024-05-23  Completed          35         5     74
#
#   product_name category
# 0   Product_13     Skin
# 1   Product_18   Makeup
# 2   Product_24     Hair
# 3   Product_42     Skin
# 4   Product_35     Skin

# %%
completed_data = pd.merge(orders_with_products,customers,how="inner",on="customer_id")

# %%
all_orders["status"].value_counts()
# Out:
# status
# Completed    1625
# Name: count, dtype: int64

# %%
pd.DataFrame(completed_data).to_excel("completed_data.xlsx", index=True)
